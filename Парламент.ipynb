# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
vyb_file = 'parlament.xlsx'
df = pd.read_excel(vyb_file)

# %%
df = df.drop(columns=["Год кампании", "Название кампании", 
                      "6.1. Количество кандидатов, участвующих в выборах", "6.2.Кол-во самовыдвиженцев",
                      "6.3.Кол-во незарегистрированных кандидатов",
                      "ЛДПР голоса", "КПРФ голоса", "СР голоса", "Новые люди",
                      "Зеленая альтернатива"
            ])

# %%
df.head(5)
# Out:
#    1.1. Кол-во населения (тыс)  1.2 Коэф рождаемости  1.3 Смертность  \
# 0                     3890.800                 1.716             7.6
# 1                     2547.700                 1.221            13.9
# 2                     4222.695                 1.550            13.7
# 3                     3395.798                 1.470            13.0
#
#    1.4 Естественный прирост населения  1.5 Доля городского населения  \
# 0                                 3.4                           81.2
# 1                                -6.6                           86.5
# 2                                -4.9                           85.9
# 3                                -2.0                           80.0
#
#    1.6 Доля сельского населения  \
# 0                          18.8
# 1                          13.5
# 2                          14.1
# 3                          20.0
#
#    2.1.Валовый региональный продукт (млрд.рублей)  2.2.ВРП на душу населения  \
# 0                                          1938.3                   1202.400
# 1                                          1883.8                    736.455
# 2                                          1032.5                    527.200
# 3                                          1500.0                    441.000
#
#    2.3.1 Обрабатывающие производства  2.3.2 добыча полезных ископаемых  ...  \
# 0                               24.1                              13.9  ...
# 1                               10.9                              41.8  ...
# 2                               15.6                              11.2  ...
# 3                               30.0                              20.0  ...
#
#    3.3.Средний долг на человека (тыс.рублей)  3.4. Уровень  безработицы (в %)  \
# 0                                      531.9                            0.031
# 1                                      335.0                            0.034
# 2                                      480.1                            0.014
# 3                                      200.0                            0.040
#
#    3.5.Инфляция или ИПЦ  \
# 0                 0.046
# 1                 0.081
# 2                 0.110
# 3                 0.050
#
#    3.6.Численность населения ниже границы бедности ( в % от общей численности населения)  \
# 0                                              0.112
# 1                                              0.098
# 2                                              0.059
# 3                                             10.000
#
#    5.1.Количество избирателей    Явка  \
# 0                     2665218  0.4816
# 1                     1896365  0.6457
# 2                     3301724  0.2847
# 3                     2600000  0.4800
#
#    5.3.Количество действительных бюллютеней  \
# 0                                   1338724
# 1                                   1203659
# 2                                    916755
# 3                                   1200000
#
#    5.4.Количество недействительных бюллютеней  5.5. Количество нарушений  \
# 0                                       19374                          3
# 1                                        7281                          0
# 2                                       23648                          0
# 3                                       50000                          3
#
#    ЕР голоса
# 0     0.7877
# 1     0.7838
# 2     0.6578
# 3     0.8130
#
# [4 rows x 28 columns]

# %%
df.describe()
# Out:
#        1.1. Кол-во населения (тыс)  1.2 Коэф рождаемости  1.3 Смертность  \
# count                     4.000000              4.000000        4.000000
# mean                   3514.248250              1.489250       12.050000
# std                     728.453613              0.206103        2.991655
# min                    2547.700000              1.221000        7.600000
# 25%                    3183.773500              1.407750       11.650000
# 50%                    3643.299000              1.510000       13.350000
# 75%                    3973.773750              1.591500       13.750000
# max                    4222.695000              1.716000       13.900000
#
#        1.4 Естественный прирост населения  1.5 Доля городского населения  \
# count                            4.000000                       4.000000
# mean                            -2.525000                      83.400000
# std                              4.382826                       3.279228
# min                             -6.600000                      80.000000
# 25%                             -5.325000                      80.900000
# 50%                             -3.450000                      83.550000
# 75%                             -0.650000                      86.050000
# max                              3.400000                      86.500000
#
#        1.6 Доля сельского населения  \
# count                      4.000000
# mean                      16.600000
# std                        3.279228
# min                       13.500000
# 25%                       13.950000
# 50%                       16.450000
# 75%                       19.100000
# max                       20.000000
#
#        2.1.Валовый региональный продукт (млрд.рублей)  \
# count                                        4.000000
# mean                                      1588.650000
# std                                        418.939252
# min                                       1032.500000
# 25%                                       1383.125000
# 50%                                       1691.900000
# 75%                                       1897.425000
# max                                       1938.300000
#
#        2.2.ВРП на душу населения  2.3.1 Обрабатывающие производства  \
# count                   4.000000                           4.000000
# mean                  726.763750                          20.150000
# std                   340.494921                           8.541858
# min                   441.000000                          10.900000
# 25%                   505.650000                          14.425000
# 50%                   631.827500                          19.850000
# 75%                   852.941250                          25.575000
# max                  1202.400000                          30.000000
#
#        2.3.2 добыча полезных ископаемых  ...  \
# count                          4.000000  ...
# mean                          21.725000  ...
# std                           13.880292  ...
# min                           11.200000  ...
# 25%                           13.225000  ...
# 50%                           16.950000  ...
# 75%                           25.450000  ...
# max                           41.800000  ...
#
#        3.3.Средний долг на человека (тыс.рублей)  \
# count                                   4.000000
# mean                                  386.750000
# std                                   149.818079
# min                                   200.000000
# 25%                                   301.250000
# 50%                                   407.550000
# 75%                                   493.050000
# max                                   531.900000
#
#        3.4. Уровень  безработицы (в %)  3.5.Инфляция или ИПЦ  \
# count                         4.000000              4.000000
# mean                          0.029750              0.071750
# std                           0.011147              0.029915
# min                           0.014000              0.046000
# 25%                           0.026750              0.049000
# 50%                           0.032500              0.065500
# 75%                           0.035500              0.088250
# max                           0.040000              0.110000
#
#        3.6.Численность населения ниже границы бедности ( в % от общей численности населения)  \
# count                                           4.000000
# mean                                            2.567250
# std                                             4.955217
# min                                             0.059000
# 25%                                             0.088250
# 50%                                             0.105000
# 75%                                             2.584000
# max                                            10.000000
#
#        5.1.Количество избирателей      Явка  \
# count                4.000000e+00  4.000000
# mean                 2.615827e+06  0.473000
# std                  5.746797e+05  0.147654
# min                  1.896365e+06  0.284700
# 25%                  2.424091e+06  0.431175
# 50%                  2.632609e+06  0.480800
# 75%                  2.824344e+06  0.522625
# max                  3.301724e+06  0.645700
#
#        5.3.Количество действительных бюллютеней  \
# count                              4.000000e+00
# mean                               1.164784e+06
# std                                1.775058e+05
# min                                9.167550e+05
# 25%                                1.129189e+06
# 50%                                1.201830e+06
# 75%                                1.237425e+06
# max                                1.338724e+06
#
#        5.4.Количество недействительных бюллютеней  5.5. Количество нарушений  \
# count                                    4.000000                   4.000000
# mean                                 25075.750000                   1.500000
# std                                  18003.886513                   1.732051
# min                                   7281.000000                   0.000000
# 25%                                  16350.750000                   0.000000
# 50%                                  21511.000000                   1.500000
# 75%                                  30236.000000                   3.000000
# max                                  50000.000000                   3.000000
#
#        ЕР голоса
# count   4.000000
# mean    0.760575
# std     0.069729
# min     0.657800
# 25%     0.752300
# 50%     0.785750
# 75%     0.794025
# max     0.813000
#
# [8 rows x 28 columns]

# %%
df1 = df[["1.1. Кол-во населения (тыс)", "1.2 Коэф рождаемости", "1.3 Смертность", "1.4 Естественный прирост населения", 
          "1.5 Доля городского населения", "1.6 Доля сельского населения","Явка"]]
df1corr = df1.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df1corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Корреляция')
plt.show()

# %%
print("Корреляция явки с другими параметрами:")
print(df1corr['Явка'].sort_values(ascending=False))
# Out:
# Корреляция явки с другими параметрами:
# Явка                                  1.000000
# 1.5 Доля городского населения         0.015077
# 1.6 Доля сельского населения         -0.015077
# 1.3 Смертность                       -0.017220
# 1.4 Естественный прирост населения   -0.104001
# 1.2 Коэф рождаемости                 -0.612852
# 1.1. Кол-во населения (тыс)          -0.923257
# Name: Явка, dtype: float64

# %%
df2 = df[["2.1.Валовый региональный продукт (млрд.рублей)", "2.2.ВРП на душу населения", "2.3.1 Обрабатывающие производства", 
          "2.3.2 добыча полезных ископаемых", "2.3.3 Транспортировка", "2.3.4 Торговля", 
          "2.4.Индекс промышленного производства (в % к предыдущему году)", 
          "2.5.Инвестиции в регион (в фактически действовавших ценах; млрд. рублей)",
          "2.6.Медианный среднедушевой денежный доход населения", "2.7. Потребительские расходы в среднем на душу населения (тыс. рублей)",
          "Явка"]]
df2corr = df2.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df2corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Корреляция')
plt.show()

# %%
print("Корреляция явки с другими параметрами:")
print(df2corr['Явка'].sort_values(ascending=False))
# Out:
# Корреляция явки с другими параметрами:
# Явка                                                                        1.000000
# 2.3.2 добыча полезных ископаемых                                            0.873301
# 2.1.Валовый региональный продукт (млрд.рублей)                              0.851853
# 2.4.Индекс промышленного производства (в % к предыдущему году)              0.782055
# 2.2.ВРП на душу населения                                                   0.274101
# 2.3.1 Обрабатывающие производства                                          -0.168562
# 2.3.3 Транспортировка                                                      -0.314847
# 2.5.Инвестиции в регион (в фактически действовавших ценах; млрд. рублей)   -0.748199
# 2.7. Потребительские расходы в среднем на душу населения (тыс. рублей)     -0.825654
# 2.3.4 Торговля                                                             -0.860545
# 2.6.Медианный среднедушевой денежный доход населения                       -0.865126
# Name: Явка, dtype: float64

# %%
df3 = df[["3.1.Уровень преступности (количество преступлений на 10 тыс. человек)", "3.2.Уровень закредитованности населения", 
          "3.3.Средний долг на человека (тыс.рублей)", "3.4. Уровень  безработицы (в %)", "3.5.Инфляция или ИПЦ", 
          "3.6.Численность населения ниже границы бедности ( в % от общей численности населения)",
          "Явка"]]
df3corr = df3.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df3corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Корреляция')
plt.show()

# %%
print("Корреляция явки с другими параметрами:")
print(df3corr['Явка'].sort_values(ascending=False))
# Out:
# Корреляция явки с другими параметрами:
# Явка                                                                                     1.000000
# 3.1.Уровень преступности (количество преступлений на 10 тыс. человек)                    0.778404
# 3.4. Уровень  безработицы (в %)                                                          0.766002
# 3.6.Численность населения ниже границы бедности ( в % от общей численности населения)    0.034979
# 3.2.Уровень закредитованности населения                                                 -0.304171
# 3.3.Средний долг на человека (тыс.рублей)                                               -0.400429
# 3.5.Инфляция или ИПЦ                                                                    -0.451179
# Name: Явка, dtype: float64

# %%
dffull = df.corr()
print("Корреляция явки с другими параметрами:")
print(dffull['Явка'].sort_values(ascending=False))
# Out:
# Корреляция явки с другими параметрами:
# Явка                                                                                     1.000000
# 2.3.2 добыча полезных ископаемых                                                         0.873301
# 2.1.Валовый региональный продукт (млрд.рублей)                                           0.851853
# 2.4.Индекс промышленного производства (в % к предыдущему году)                           0.782055
# 3.1.Уровень преступности (количество преступлений на 10 тыс. человек)                    0.778404
# ЕР голоса                                                                                0.775848
# 3.4. Уровень  безработицы (в %)                                                          0.766002
# 5.3.Количество действительных бюллютеней                                                 0.701528
# 2.2.ВРП на душу населения                                                                0.274101
# 5.5. Количество нарушений                                                                0.060998
# 3.6.Численность населения ниже границы бедности ( в % от общей численности населения)    0.034979
# 1.5 Доля городского населения                                                            0.015077
# 1.6 Доля сельского населения                                                            -0.015077
# 1.3 Смертность                                                                          -0.017220
# 1.4 Естественный прирост населения                                                      -0.104001
# 2.3.1 Обрабатывающие производства                                                       -0.168562
# 3.2.Уровень закредитованности населения                                                 -0.304171
# 2.3.3 Транспортировка                                                                   -0.314847
# 5.4.Количество недействительных бюллютеней                                              -0.335907
# 3.3.Средний долг на человека (тыс.рублей)                                               -0.400429
# 3.5.Инфляция или ИПЦ                                                                    -0.451179
# 1.2 Коэф рождаемости                                                                    -0.612852
# 2.5.Инвестиции в регион (в фактически действовавших ценах; млрд. рублей)                -0.748199
# 2.7. Потребительские расходы в среднем на душу населения (тыс. рублей)                  -0.825654
# 2.3.4 Торговля                                                                          -0.860545
# 2.6.Медианный среднедушевой денежный доход населения                                    -0.865126
# 1.1. Кол-во населения (тыс)                                                             -0.923257
# 5.1.Количество избирателей                                                              -0.994226
# Name: Явка, dtype: float64

# %%
df4 = df[["1.1. Кол-во населения (тыс)", "1.2 Коэф рождаемости", "1.3 Смертность", "1.4 Естественный прирост населения", 
          "1.5 Доля городского населения", "1.6 Доля сельского населения","ЕР голоса"]]
df4corr = df4.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df4corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Корреляция')
plt.show()

# %%
print("Корреляция ЕР голосов с другими параметрами:")
print(df4corr['ЕР голоса'].sort_values(ascending=False))
# Out:
# Корреляция ЕР голосов с другими параметрами:
# ЕР голоса                             1.000000
# 1.6 Доля сельского населения          0.616443
# 1.4 Естественный прирост населения    0.368323
# 1.2 Коэф рождаемости                 -0.170068
# 1.3 Смертность                       -0.315614
# 1.1. Кол-во населения (тыс)          -0.598853
# 1.5 Доля городского населения        -0.616443
# Name: ЕР голоса, dtype: float64

# %%
df5 = df[["2.1.Валовый региональный продукт (млрд.рублей)", "2.2.ВРП на душу населения", "2.3.1 Обрабатывающие производства", 
          "2.3.2 добыча полезных ископаемых", "2.3.3 Транспортировка", "2.3.4 Торговля", 
          "2.4.Индекс промышленного производства (в % к предыдущему году)", 
          "2.5.Инвестиции в регион (в фактически действовавших ценах; млрд. рублей)",
          "2.6.Медианный среднедушевой денежный доход населения", "2.7. Потребительские расходы в среднем на душу населения (тыс. рублей)",
          "ЕР голоса"]]
df5corr = df5.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df5corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Корреляция')
plt.show()

# %%
print("Корреляция ЕР голосов с другими параметрами:")
print(df5corr['ЕР голоса'].sort_values(ascending=False))
# Out:
# Корреляция ЕР голосов с другими параметрами:
# ЕР голоса                                                                   1.000000
# 2.4.Индекс промышленного производства (в % к предыдущему году)              0.980211
# 2.1.Валовый региональный продукт (млрд.рублей)                              0.785634
# 2.3.1 Обрабатывающие производства                                           0.490434
# 2.3.2 добыча полезных ископаемых                                            0.428874
# 2.3.3 Транспортировка                                                       0.342287
# 2.2.ВРП на душу населения                                                   0.261920
# 2.7. Потребительские расходы в среднем на душу населения (тыс. рублей)     -0.338904
# 2.6.Медианный среднедушевой денежный доход населения                       -0.892989
# 2.3.4 Торговля                                                             -0.970126
# 2.5.Инвестиции в регион (в фактически действовавших ценах; млрд. рублей)   -0.992873
# Name: ЕР голоса, dtype: float64

# %%
df6 = df[["3.1.Уровень преступности (количество преступлений на 10 тыс. человек)", "3.2.Уровень закредитованности населения", 
          "3.3.Средний долг на человека (тыс.рублей)", "3.4. Уровень  безработицы (в %)", "3.5.Инфляция или ИПЦ", 
          "3.6.Численность населения ниже границы бедности ( в % от общей численности населения)",
          "ЕР голоса"]]
df6corr = df6.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df6corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Корреляция')
plt.show()

# %%
print("Корреляция ЕР голосов с другими параметрами:")
print(df6corr['ЕР голоса'].sort_values(ascending=False))
# Out:
# Корреляция ЕР голосов с другими параметрами:
# ЕР голоса                                                                                1.000000
# 3.4. Уровень  безработицы (в %)                                                          0.981530
# 3.1.Уровень преступности (количество преступлений на 10 тыс. человек)                    0.978658
# 3.6.Численность населения ниже границы бедности ( в % от общей численности населения)    0.505035
# 3.2.Уровень закредитованности населения                                                 -0.348817
# 3.3.Средний долг на человека (тыс.рублей)                                               -0.531245
# 3.5.Инфляция или ИПЦ                                                                    -0.887692
# Name: ЕР голоса, dtype: float64

# %%
dffull = df.corr()
print("Корреляция ЕР голосов с другими параметрами:")
print(dffull['ЕР голоса'].sort_values(ascending=False))
# Out:
# Корреляция ЕР голосов с другими параметрами:
# ЕР голоса                                                                                1.000000
# 3.4. Уровень  безработицы (в %)                                                          0.981530
# 2.4.Индекс промышленного производства (в % к предыдущему году)                           0.980211
# 3.1.Уровень преступности (количество преступлений на 10 тыс. человек)                    0.978658
# 5.3.Количество действительных бюллютеней                                                 0.887607
# 2.1.Валовый региональный продукт (млрд.рублей)                                           0.785634
# Явка                                                                                     0.775848
# 5.5. Количество нарушений                                                                0.658671
# 1.6 Доля сельского населения                                                             0.616443
# 3.6.Численность населения ниже границы бедности ( в % от общей численности населения)    0.505035
# 2.3.1 Обрабатывающие производства                                                        0.490434
# 2.3.2 добыча полезных ископаемых                                                         0.428874
# 1.4 Естественный прирост населения                                                       0.368323
# 2.3.3 Транспортировка                                                                    0.342287
# 2.2.ВРП на душу населения                                                                0.261920
# 5.4.Количество недействительных бюллютеней                                               0.235106
# 1.2 Коэф рождаемости                                                                    -0.170068
# 1.3 Смертность                                                                          -0.315614
# 2.7. Потребительские расходы в среднем на душу населения (тыс. рублей)                  -0.338904
# 3.2.Уровень закредитованности населения                                                 -0.348817
# 3.3.Средний долг на человека (тыс.рублей)                                               -0.531245
# 1.1. Кол-во населения (тыс)                                                             -0.598853
# 1.5 Доля городского населения                                                           -0.616443
# 5.1.Количество избирателей                                                              -0.721147
# 3.5.Инфляция или ИПЦ                                                                    -0.887692
# 2.6.Медианный среднедушевой денежный доход населения                                    -0.892989
# 2.3.4 Торговля                                                                          -0.970126
# 2.5.Инвестиции в регион (в фактически действовавших ценах; млрд. рублей)                -0.992873
# Name: ЕР голоса, dtype: float64
